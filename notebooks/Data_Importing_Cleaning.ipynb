# %%
import pandas as pd

# %%
Headway_Data = pd.read_excel('../Data/Headway Data, 8-1-2023 to 9-30-2023.xlsx')

# %%
Headway_Data.head(5)
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID       DATE  ROUTE_ABBR  BLOCK_ABBR  \
# 0    120230801             1      99457890 2023-08-01          22        2200
# 1    120230801             1      99457891 2023-08-01          22        2200
# 2    120230801             1      99457892 2023-08-01          22        2200
# 3    120230801             1      99457893 2023-08-01          22        2200
# 4    120230801             1      99457894 2023-08-01          22        2200
#
#    OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ... ACTUAL_HDWY  \
# 0      1040   345104            0          TO DOWNTOWN  ...         NaN
# 1      1040   345104            0          TO DOWNTOWN  ...         NaN
# 2      1040   345104            0          TO DOWNTOWN  ...         NaN
# 3      1040   345104            0          TO DOWNTOWN  ...         NaN
# 4      1040   345105            0        FROM DOWNTOWN  ...         NaN
#
# ...

# %%
Headway_Data.columns
# Out:
# Index(['CALENDAR_ID', 'SERVICE_ABBR', 'ADHERENCE_ID', 'DATE', 'ROUTE_ABBR',
#        'BLOCK_ABBR', 'OPERATOR', 'TRIP_ID', 'OVERLOAD_ID',
#        'ROUTE_DIRECTION_NAME', 'TIME_POINT_ABBR', 'ROUTE_STOP_SEQUENCE',
#        'TRIP_EDGE', 'LATITUDE', 'LONGITUDE', 'SCHEDULED_TIME',
#        'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'ADHERENCE',
#        'SCHEDULED_HDWY', 'ACTUAL_HDWY', 'HDWY_DEV', 'ADJUSTED_EARLY_COUNT',
#        'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT', 'STOP_CANCELLED',
#        'PREV_SCHED_STOP_CANCELLED', 'IS_RELIEF', 'BLOCK_STOP_ORDER',
#        'DWELL_IN_MINS'],
#       dtype='object')

# %%
Hdwy_data = Headway_Data.copy()

# %%
Hdwy_data['hdwy_dev_percent'] = Hdwy_data['HDWY_DEV']/Hdwy_data['SCHEDULED_HDWY']

# %%
Hdwy_data.head()
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID       DATE  ROUTE_ABBR  BLOCK_ABBR  \
# 0    120230801             1      99457890 2023-08-01          22        2200
# 1    120230801             1      99457891 2023-08-01          22        2200
# 2    120230801             1      99457892 2023-08-01          22        2200
# 3    120230801             1      99457893 2023-08-01          22        2200
# 4    120230801             1      99457894 2023-08-01          22        2200
#
#    OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ... HDWY_DEV  \
# 0      1040   345104            0          TO DOWNTOWN  ...      NaN
# 1      1040   345104            0          TO DOWNTOWN  ...      NaN
# 2      1040   345104            0          TO DOWNTOWN  ...      NaN
# 3      1040   345104            0          TO DOWNTOWN  ...      NaN
# 4      1040   345105            0        FROM DOWNTOWN  ...      NaN
#
#    ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  ADJUSTED_ONTIME_COUNT  \
# ...

# %%
import numpy as np
Hdwy_data['HDWY_DEV'].hist(bins=100)
# Out:
# <Axes: >

# %%
np.sqrt(Hdwy_data['HDWY_DEV']).hist(bins=100)
# Out:
# /home/prahlad/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: >

# %%
Hdwy_data['ROUTE_DIRECTION_NAME'].nunique()
# Out:
# 2
